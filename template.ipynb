# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("pendulum_trajectories.csv")
print(df[["theta", "omega"]].describe())
# Out:
#               theta         omega
# count  10020.000000  10020.000000
# mean      -0.769939     -0.342682
# std        3.065709      3.066135
# min      -14.708250     -6.608891
# 25%       -1.357053     -2.405475
# 50%       -0.196477     -0.421438
# 75%        0.798967      1.754675
# max        8.578157      6.505975

# %%
df["theta"] = (df["theta"] + np.pi) % (2 * np.pi) - np.pi
df["theta_next"] = (df["theta_next"] + np.pi) % (2 * np.pi) - np.pi
print(df[["theta", "omega"]].describe())
# Out:
#               theta         omega
# count  10020.000000  10020.000000
# mean       0.022671     -0.342682
# std        1.489264      3.066135
# min       -3.141532     -6.608891
# 25%       -1.019101     -2.405475
# 50%        0.008608     -0.421438
# 75%        1.094539      1.754675
# max        3.141124      6.505975
